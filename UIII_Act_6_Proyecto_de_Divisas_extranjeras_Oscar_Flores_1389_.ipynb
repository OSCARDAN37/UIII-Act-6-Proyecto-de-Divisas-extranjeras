# %% [markdown]
# <a href="https://colab.research.google.com/github/OSCARDAN37/UIII-Act-6-Proyecto-de-Divisas-extranjeras/blob/main/UIII_Act_6_Proyecto_de_Divisas_extranjeras_Oscar_Flores_1389_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Oscar Flores** Fecha 19/Mayo/2026
# # NL = 19
# # Act 6 Proyecto de simulación de Divisas extranjeras

# %%
print("==========================================")
print("🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖")
print("==========================================")

continuar = "si"

while continuar == "si":
    print("\n--- MENÚ DE DESTINOS ---")
    print("1. Viajar a Europa (Euros - EUR)")
    print("2. Viajar a México (Pesos - MXN)")
    print("3. Salir del asistente")

    opcion = input("Selecciona tu destino deseado (1, 2 o 3): ")

    if opcion == "1":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        euros = dolares * 0.92
        print("Tu dinero equivale a:", euros, "Euros.")

        if euros < 800:
            print("🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.")
        else:
            print("🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.")

    elif opcion == "2":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        pesos = dolares * 16.80
        print("Tu dinero equivale a:", pesos, "Pesos Mexicanos.")

        if pesos < 10000:
            print("🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.")
        else:
            print("🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.")

    elif opcion == "3":
        print("🤖 Asistente apagado. ¡Buen viaje!")
        continuar = "no"

    else:
        print("❌ Opción incorrecta. Elige 1, 2 o 3.")

    if opcion != "3":
        continuar = input("\n¿Quieres consultar otro destino? (si/no): ")

print("==========================================")
print("Programa realizado por Oscar Flores NL = 22")
# Out:
# ...
# 🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖
# ...
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 1
# ¿Cuántos dólares (USD) tienes para tu viaje?: 800
# Tu dinero equivale a: 736.0 Euros.
# 🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.
#
# ¿Quieres consultar otro destino? (si/no): no
# ...
# Programa realizado por Oscar Flores NL = 22

# %%
print("==========================================")
print("🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖")
print("==========================================")

continuar = "si"

while continuar == "si":
    print("\n--- MENÚ DE DESTINOS ---")
    print("1. Viajar a Europa (Euros - EUR)")
    print("2. Viajar a México (Pesos - MXN)")
    print("3. Salir del asistente")

    opcion = input("Selecciona tu destino deseado (1, 2 o 3): ")

    if opcion == "1":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        euros = dolares * 0.92
        print("Tu dinero equivale a:", euros, "Euros.")

        if euros < 800:
            print("🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.")
        else:
            print("🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.")

    elif opcion == "2":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        pesos = dolares * 16.80
        print("Tu dinero equivale a:", pesos, "Pesos Mexicanos.")

        if pesos < 10000:
            print("🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.")
        else:
            print("🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.")

    elif opcion == "3":
        print("🤖 Asistente apagado. ¡Buen viaje!")
        continuar = "no"

    else:
        print("❌ Opción incorrecta. Elige 1, 2 o 3.")

    if opcion != "3":
        continuar = input("\n¿Quieres consultar otro destino? (si/no): ")

print("==========================================")
print("Programa realizado por Oscar Flores NL = 22")
# Out:
# ...
# 🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖
# ...
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 2
# ¿Cuántos dólares (USD) tienes para tu viaje?: 500
# Tu dinero equivale a: 8400.0 Pesos Mexicanos.
# 🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.
#
# ¿Quieres consultar otro destino? (si/no): no
# ...
# Programa realizado por Oscar Flores NL = 22

# %%
print("==========================================")
print("🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖")
print("==========================================")

continuar = "si"

while continuar == "si":
    print("\n--- MENÚ DE DESTINOS ---")
    print("1. Viajar a Europa (Euros - EUR)")
    print("2. Viajar a México (Pesos - MXN)")
    print("3. Salir del asistente")

    opcion = input("Selecciona tu destino deseado (1, 2 o 3): ")

    if opcion == "1":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        euros = dolares * 0.92
        print("Tu dinero equivale a:", euros, "Euros.")

        if euros < 800:
            print("🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.")
        else:
            print("🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.")

    elif opcion == "2":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        pesos = dolares * 16.80
        print("Tu dinero equivale a:", pesos, "Pesos Mexicanos.")

        if pesos < 10000:
            print("🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.")
        else:
            print("🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.")

    elif opcion == "3":
        print("🤖 Asistente apagado. ¡Buen viaje!")
        continuar = "no"

    else:
        print("❌ Opción incorrecta. Elige 1, 2 o 3.")

    if opcion != "3":
        continuar = input("\n¿Quieres consultar otro destino? (si/no): ")

print("==========================================")
print("Programa realizado por Oscar Flores NL = 22")
# Out:
# ...
# 🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖
# ...
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 1
# ¿Cuántos dólares (USD) tienes para tu viaje?: 1000
# Tu dinero equivale a: 920.0 Euros.
# 🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.
#
# ¿Quieres consultar otro destino? (si/no): no
# ...
# Programa realizado por Oscar Flores NL = 22

# %%
print("==========================================")
print("🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖")
print("==========================================")

continuar = "si"

while continuar == "si":
    print("\n--- MENÚ DE DESTINOS ---")
    print("1. Viajar a Europa (Euros - EUR)")
    print("2. Viajar a México (Pesos - MXN)")
    print("3. Salir del asistente")

    opcion = input("Selecciona tu destino deseado (1, 2 o 3): ")

    if opcion == "1":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        euros = dolares * 0.92
        print("Tu dinero equivale a:", euros, "Euros.")

        if euros < 800:
            print("🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.")
        else:
            print("🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.")

    elif opcion == "2":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        pesos = dolares * 16.80
        print("Tu dinero equivale a:", pesos, "Pesos Mexicanos.")

        if pesos < 10000:
            print("🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.")
        else:
            print("🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.")

    elif opcion == "3":
        print("🤖 Asistente apagado. ¡Buen viaje!")
        continuar = "no"

    else:
        print("❌ Opción incorrecta. Elige 1, 2 o 3.")

    if opcion != "3":
        continuar = input("\n¿Quieres consultar otro destino? (si/no): ")

print("==========================================")
print("Programa realizado por Oscar Flores NL = 22")
# Out:
# ...
# 🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖
# ...
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 2
# ¿Cuántos dólares (USD) tienes para tu viaje?: 1000
# Tu dinero equivale a: 16800.0 Pesos Mexicanos.
# 🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.
#
# ¿Quieres consultar otro destino? (si/no): no
# ...
# Programa realizado por Oscar Flores NL = 22

# %%
print("==========================================")
print("🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖")
print("==========================================")

continuar = "si"

while continuar == "si":
    print("\n--- MENÚ DE DESTINOS ---")
    print("1. Viajar a Europa (Euros - EUR)")
    print("2. Viajar a México (Pesos - MXN)")
    print("3. Salir del asistente")

    opcion = input("Selecciona tu destino deseado (1, 2 o 3): ")

    if opcion == "1":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        euros = dolares * 0.92
        print("Tu dinero equivale a:", euros, "Euros.")

        if euros < 800:
            print("🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.")
        else:
            print("🤖 IA Dice: ¡Presupuesto excelente! Tienes suficiente para disfrutar Europa.")

    elif opcion == "2":
        dolares = float(input("¿Cuántos dólares (USD) tienes para tu viaje?: "))
        pesos = dolares * 16.80
        print("Tu dinero equivale a:", pesos, "Pesos Mexicanos.")

        if pesos < 10000:
            print("🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.")
        else:
            print("🤖 IA Dice: ¡Presupuesto genial! Podrás pasar unas vacaciones muy cómodas.")

    elif opcion == "3":
        print("🤖 Asistente apagado. ¡Buen viaje!")
        continuar = "no"

    else:
        print("❌ Opción incorrecta. Elige 1, 2 o 3.")

    if opcion != "3":
        continuar = input("\n¿Quieres consultar otro destino? (si/no): ")

print("==========================================")
print("Programa realizado por Oscar Flores NL = 22")
# Out:
# ...
# 🤖 ASISTENTE DE VIAJES INTELIGENTE 🤖
# ...
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 1
# ¿Cuántos dólares (USD) tienes para tu viaje?: 800
# Tu dinero equivale a: 736.0 Euros.
# 🤖 IA Dice: Presupuesto bajo para Europa. Te sugiero ahorrar un poco más.
#
# ¿Quieres consultar otro destino? (si/no): si
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 2
# ¿Cuántos dólares (USD) tienes para tu viaje?: 500
# Tu dinero equivale a: 8400.0 Pesos Mexicanos.
# 🤖 IA Dice: Presupuesto ajustado. Deberás buscar hoteles económicos.
#
# ¿Quieres consultar otro destino? (si/no): si
#
# --- MENÚ DE DESTINOS ---
# 1. Viajar a Europa (Euros - EUR)
# 2. Viajar a México (Pesos - MXN)
# 3. Salir del asistente
# Selecciona tu destino deseado (1, 2 o 3): 1
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/OSCARDAN37/UIII-Act-6-Proyecto-de-Divisas-extranjeras/refs/heads/main/InfoViajes.png)
